# %%
import numpy as np
import pandas as pd
import statistics as st

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\madhu'

# %%
os.chdir('Downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\madhu\\Downloads'

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#        age           job   marital education_qual  call_type  day  mon   dur  \
# 0       58    management   married       tertiary    unknown    5  may   261
# 1       44    technician    single      secondary    unknown    5  may   151
# 2       33  entrepreneur   married      secondary    unknown    5  may    76
# 3       47   blue-collar   married        unknown    unknown    5  may    92
# 4       33       unknown    single        unknown    unknown    5  may   198
# ...    ...           ...       ...            ...        ...  ...  ...   ...
# 45206   51    technician   married       tertiary   cellular   17  nov   977
# 45207   71       retired  divorced        primary   cellular   17  nov   456
# 45208   72       retired   married      secondary   cellular   17  nov  1127
# 45209   57   blue-collar   married      secondary  telephone   17  nov   508
# 45210   37  entrepreneur   married      secondary   cellular   17  nov   361
#
#        num_calls prev_outcome    y
# ...

# %%
df.head()
# Out:
#    age           job  marital education_qual call_type  day  mon  dur  \
# 0   58    management  married       tertiary   unknown    5  may  261
# 1   44    technician   single      secondary   unknown    5  may  151
# 2   33  entrepreneur  married      secondary   unknown    5  may   76
# 3   47   blue-collar  married        unknown   unknown    5  may   92
# 4   33       unknown   single        unknown   unknown    5  may  198
#
#    num_calls prev_outcome   y
# 0          1      unknown  no
# 1          1      unknown  no
# 2          1      unknown  no
# 3          1      unknown  no
# 4          1      unknown  no

# %%
df.shape
# Out:
# (45211, 11)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education_qual', 'call_type', 'day', 'mon',
#        'dur', 'num_calls', 'prev_outcome', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45211 non-null  int64
#  1   job             45211 non-null  object
#  2   marital         45211 non-null  object
#  3   education_qual  45211 non-null  object
#  4   call_type       45211 non-null  object
#  5   day             45211 non-null  int64
#  6   mon             45211 non-null  object
#  7   dur             45211 non-null  int64
#  8   num_calls       45211 non-null  int64
#  9   prev_outcome    45211 non-null  object
#  10  y               45211 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.8+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education_qual    0
# call_type         0
# day               0
# mon               0
# dur               0
# num_calls         0
# prev_outcome      0
# y                 0
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# job               object
# marital           object
# education_qual    object
# call_type         object
# day                int64
# mon               object
# dur                int64
# num_calls          int64
# prev_outcome      object
# y                 object
# dtype: object

# %%
df['age'].value_counts()
# Out:
# age
# 32    2085
# 31    1996
# 33    1972
# 34    1930
# 35    1894
#       ...
# 93       2
# 90       2
# 95       2
# 88       2
# 94       1
# Name: count, Length: 77, dtype: int64

# %%
df['job'].value_counts()
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %%
df['marital'].value_counts()
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %%
df['education_qual'].value_counts()
# Out:
# education_qual
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64

# %%
df['call_type'].value_counts()
# Out:
# call_type
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# 20    2752
# 18    2308
# 21    2026
# 17    1939
# 6     1932
# 5     1910
# 14    1848
# 8     1842
# 28    1830
# 7     1817
# 19    1757
# 29    1745
# 15    1703
# 12    1603
# 13    1585
# 30    1566
# 9     1561
# 11    1479
# 4     1445
# 16    1415
# 2     1293
# 27    1121
# 3     1079
# 26    1035
# 23     939
# 22     905
# 25     840
# 31     643
# 10     524
# 24     447
# 1      322
# Name: count, dtype: int64

# %%
df['mon'].value_counts()
# Out:
# mon
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %%
df['dur'].value_counts()
# Out:
# dur
# 124     188
# 90      184
# 89      177
# 104     175
# 122     175
#        ...
# 1833      1
# 1545      1
# 1352      1
# 1342      1
# 1556      1
# Name: count, Length: 1573, dtype: int64

# %%
df['num_calls'].value_counts()
# Out:
# num_calls
# 1     17544
# 2     12505
# 3      5521
# 4      3522
# 5      1764
# 6      1291
# 7       735
# 8       540
# 9       327
# 10      266
# 11      201
# 12      155
# 13      133
# 14       93
# 15       84
# 16       79
# 17       69
# 18       51
# 19       44
# 20       43
# 21       35
# 22       23
# 25       22
# 23       22
# 24       20
# 29       16
# 28       16
# 26       13
# 31       12
# 27       10
# 32        9
# 30        8
# 33        6
# 34        5
# 36        4
# 35        4
# 43        3
# 38        3
# 37        2
# 50        2
# 41        2
# 46        1
# 58        1
# 55        1
# 63        1
# 51        1
# 39        1
# 44        1
# Name: count, dtype: int64

# %%
df['prev_outcome'].value_counts()
# Out:
# prev_outcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %%
df['y'].value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#        age           job   marital education_qual  call_type  day  mon   dur  \
# 0       58    management   married       tertiary    unknown    5  may   261
# 1       44    technician    single      secondary    unknown    5  may   151
# 2       33  entrepreneur   married      secondary    unknown    5  may    76
# 3       47   blue-collar   married        unknown    unknown    5  may    92
# 4       33       unknown    single        unknown    unknown    5  may   198
# ...    ...           ...       ...            ...        ...  ...  ...   ...
# 45206   51    technician   married       tertiary   cellular   17  nov   977
# 45207   71       retired  divorced        primary   cellular   17  nov   456
# 45208   72       retired   married      secondary   cellular   17  nov  1127
# 45209   57   blue-collar   married      secondary  telephone   17  nov   508
# 45210   37  entrepreneur   married      secondary   cellular   17  nov   361
#
#        num_calls prev_outcome    y
# ...

# %%
df.shape
# Out:
# (45205, 11)

# %% [markdown]
# # EDA

# %%
 pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
global df

# %%
sns.set_theme(style='darkgrid',palette='pastel')

plt.figure(figsize=(40,25))
plt.subplot(431)
sns.countplot(x ='job', data = df)
plt.xticks(rotation=15)
plt.xlabel('job')
plt.ylabel('Count')
plt.title('field of the person')

plt.subplot(432)
sns.countplot(x='marital',data=df)
plt.xticks(rotation=15)
plt.xlabel('marital')
plt.ylabel('Count')
plt.title('marital status of the given person')

plt.subplot(433)
sns.countplot(x='education_qual', data=df)
plt.xticks(rotation=15)
plt.xlabel('education_qual')
plt.ylabel('Count')
plt.title('education qualification for the person')

plt.subplot(434)
sns.countplot(x='call_type',data=df)
plt.xticks(rotation=15)
plt.xlabel('call_type')
plt.ylabel('Count')
plt.title('calling type')

plt.subplot(435)
sns.countplot(x='mon',data=df)
plt.xticks(rotation=15)
plt.xlabel('mon')
plt.ylabel('Count')
plt.title('month of the year')

plt.subplot(436)
sns.countplot(x='prev_outcome',data=df)
plt.xticks(rotation=15)
plt.xlabel('prev_outcome')
plt.ylabel('Count')
plt.title('outgoing calls to the person')

plt.subplot(437)
sns.countplot(x='y',data=df)
plt.xticks(rotation=15)
plt.xlabel('y')
plt.ylabel('Count')
plt.title('yes or no')

plt.show()

# %%
plt.figure(figsize=(50,30))

plt.subplot(431)
sns.barplot(x=df.job, y=df.age, alpha=0.8)
plt.xlabel('Job')
plt.ylabel('Mean age')
plt.title('Job vs Mean_age')
# Out:
# Text(0.5, 1.0, 'Job vs Mean_age')

# %%
job_order = df.groupby('job')['age'].mean().reset_index().sort_values('age')['job']
marital_order = df.groupby('marital')['age'].mean().reset_index().sort_values('age')['marital']
education_qual_order = df.groupby('education_qual')['age'].mean().reset_index().sort_values('age')['education_qual']
call_type_order = df.groupby('call_type')['age'].mean().reset_index().sort_values('age')['call_type']
mon_order = df.groupby('mon')['age'].mean().reset_index().sort_values('age')['mon']
prev_outcome_order = df.groupby('prev_outcome')['age'].mean().reset_index().sort_values('age')['prev_outcome']
y_order = df.groupby('y')['age'].mean().reset_index().sort_values('age')['y']

# %%
df.groupby('job')['age'].mean().reset_index().sort_values('age')['job'].values
# Out:
# array(['student', 'services', 'admin.', 'technician', 'blue-collar',
#        'management', 'self-employed', 'unemployed', 'entrepreneur',
#        'housemaid', 'unknown', 'retired'], dtype=object)

# %%
plt.figure(figsize=(40,25))

plt.subplot(431)
sns.barplot(x=df.job, y=df.age, order = job_order)
plt.xlabel('Job')
plt.ylabel('Mean Age')
plt.title('Job vs Mean_Age')

plt.subplot(432)
sns.barplot(x=df.marital, y=df.age, order=marital_order)
plt.xlabel('Marital')
plt.ylabel('Mean Age')
plt.title('Marital vs Mean_Age')

plt.subplot(433)
sns.barplot(x=df.education_qual, y=df.age, order=education_qual_order)
plt.xlabel('Education_qual')
plt.ylabel('Mean Age')
plt.title('Education_qual vs Mean_Age')

plt.subplot(434)
sns.barplot(x=df.call_type, y=df.age, order=call_type_order)
plt.xlabel('Call_type')
plt.ylabel('Mean Age')
plt.title('Call_type vs Mean_Age')

plt.subplot(435)
sns.barplot(x=df.mon, y=df.age, order=mon_order)
plt.xlabel('Mon')
plt.ylabel('Mean Age')
plt.title('Mon vs Mean_Age')

plt.subplot(436)
sns.barplot(x=df.prev_outcome, y=df.age ,order=prev_outcome_order)
plt.xlabel('Prev_outcome')
plt.ylabel('Mean Age')
plt.title('Prev_outcome vs Mean_Age')

plt.subplot(437)
sns.barplot(x=df.y, y=df.age  ,order=y_order)
plt.xlabel('Y')
plt.ylabel('Mean Age')
plt.title('Y vs Age')

plt.tight_layout()

# %%
plt.figure(figsize=(20,25))

plt.subplot(331)
sns.scatterplot(x=df.day, y=df.age)
plt.xlabel('Day')
plt.ylabel(' Age')
plt.title('Day  of the monthvs Age')

plt.subplot(332)
sns.scatterplot(x=df.dur, y=df.age)
plt.xlabel('Dur')
plt.ylabel(' Age')
plt.title('Duration of calls vs Age')

plt.subplot(333)
sns.lineplot(x=df.num_calls, y=df.age)
plt.xlabel('Num_calls')
plt.ylabel(' Age')
plt.title('Number of calls vs Age')

plt.tight_layout()

# %%
plt.figure(figsize=(20,25))

plt.subplot(331)
sns.lineplot(x=df.day, y=df.age)
plt.xlabel('Day')
plt.ylabel(' Age')
plt.title('Day  of the monthvs Age')

plt.subplot(332)
sns.lineplot(x=df.dur, y=df.age)
plt.xlabel('Dur')
plt.ylabel(' Age')
plt.title('Duration of calls vs Age')

plt.subplot(333)
sns.lineplot(x=df.num_calls, y=df.age)
plt.xlabel('Num_calls')
plt.ylabel(' Age')
plt.title('Number of calls vs Age')
# Out:
# Text(0.5, 1.0, 'Number of calls vs Age')

# %%
sns.boxplot(df['call_type'])
# Out:
# <Axes: ylabel='call_type'>

# %% [markdown]
# # ENCODING

# %%
df['job'] = df['job'].map({'technician':0,'management':1,'entrepreneur':2,'blue-collar':3,'services':4,'self-employed':5,'admin.':6,'unknown':7,'retired':8,'unemployed':9,'housemaid':10,'student':11})
df['marital'] = df['marital'].map({'married':0,'single':1,'divorced':2})
df['education_qual'] = df['education_qual'].map({'primary':0,'secondary':1,'tertiary':2,'unknown':3})
df['call_type'] = df['call_type'].map({'unknown':0,'cellular':1,'telephone':2})
df['mon'] = df['mon'].map({'jan':0,'feb':1,'mar':2,'apr':3,'may':4,'jun':5,'jul':6,'aug':7,'sep':8,'oct':9,'nov':10,'dec':11})
df['prev_outcome'] = df['prev_outcome'].map({'unknown':0,'success':1,'failure':2,'other':3})
df['y'] = df['y'].map({'yes':0,'no':1})
# Out:
# C:\Users\madhu\AppData\Local\Temp\ipykernel_16000\2058868034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job'] = df['job'].map({'technician':0,'management':1,'entrepreneur':2,'blue-collar':3,'services':4,'self-employed':5,'admin.':6,'unknown':7,'retired':8,'unemployed':9,'housemaid':10,'student':11})
# C:\Users\madhu\AppData\Local\Temp\ipykernel_16000\2058868034.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.head()
# Out:
#    age  job  marital  education_qual  call_type  day  mon  dur  num_calls  \
# 0   58    1        0               2          0    5    4  261          1
# 1   44    0        1               1          0    5    4  151          1
# 2   33    2        0               1          0    5    4   76          1
# 3   47    3        0               3          0    5    4   92          1
# 4   33    7        1               3          0    5    4  198          1
#
#    prev_outcome  y
# 0             0  1
# 1             0  1
# 2             0  1
# 3             0  1
# 4             0  1

# %%
X =df.drop('age',axis=1)
y = df['age']

# %%
X.isnull().sum()
# Out:
# job               0
# marital           0
# education_qual    0
# call_type         0
# day               0
# mon               0
# dur               0
# num_calls         0
# prev_outcome      0
# y                 0
# dtype: int64

# %%
y
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45205, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=70)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (36164, 10) (9041, 10) (36164,) (9041,)

# %%
X_train
# Out:
#        job  marital  education_qual  call_type  day  mon   dur  num_calls  \
# 2955     0        1               3          0   14    4  1028          2
# 18005    2        2               3          1   30    6   988          2
# 36166    3        0               3          1   11    4   306          1
# 3657     0        0               1          0   16    4   248          3
# 11307    5        0               1          0   18    5   313          2
# ...    ...      ...             ...        ...  ...  ...   ...        ...
# 21569   10        0               0          1   19    7   111          4
# 25922    9        0               2          1   19   10   394          2
# 44830    8        0               0          2   17    8   231          1
# 21624    0        0               1          1   19    7    35          4
# 23892    4        0               1          1   29    7   155          2
#
#        prev_outcome  y
# 2955              0  0
# 18005             0  0
# ...

# %% [markdown]
# # MACHINE LEARNING MODEL

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
import xgboost as xgb

# %% [markdown]
#  LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(fit_intercept=True) 
linear_model.fit(X_train,y_train)
print(linear_model.predict(X_test))    
print(y_test)
# Out:
# [38.89579457 38.30843166 39.75784717 ... 40.61388419 35.27317607
#  44.83393073]
# 20834    30
# 6563     44
# 35616    28
# 27751    42
# 2775     42
#          ..
# 37957    24
# 31757    40
# 21160    52
# 9050     56
# 18892    58
# Name: age, Length: 9041, dtype: int64

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.049891563446235576

# %%
from sklearn.model_selection import cross_val_score
# synatx : cross_val_score(model, fts_train, target_train, bins).mean()
cross_val_linear_model=cross_val_score(linear_model,X_train,y_train,cv=10).mean()
cross_val_linear_model
# Out:
# 0.05629461698293566

# %% [markdown]
#  K NEARNEST NEIGHBOR REGRESSION

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_values=np.arange(1,50)
cross_val_knn=[]
for k in knn_values:
    knn_regressor=KNeighborsRegressor(n_neighbors=k)
    knn_regressor.fit(X_train_scaled,y_train)
    print("K value : ", k, " train score : ", knn_regressor.score(X_train_scaled,y_train)  ,"cross_val_score : ", cross_val_score(knn_regressor,X_train_scaled,y_train,cv = 10).mean())
    cross_val_knn.append(cross_val_score(knn_regressor,X_train_scaled,y_train,cv = 10).mean())
# Out:
# K value :  1  train score :  0.9963598783225793 cross_val_score :  -0.16137859342675728
# K value :  2  train score :  0.711594168065148 cross_val_score :  0.11998017870975479
# K value :  3  train score :  0.6116545004248948 cross_val_score :  0.21165203490356524
# K value :  4  train score :  0.558887144205003 cross_val_score :  0.2560378894916441
# K value :  5  train score :  0.5277822971452892 cross_val_score :  0.2784224471615953
# K value :  6  train score :  0.5041886002450047 cross_val_score :  0.2930268718235139
# K value :  7  train score :  0.48566157792185083 cross_val_score :  0.3048738003034855
# K value :  8  train score :  0.4713797346393719 cross_val_score :  0.31188456304000345
# K value :  9  train score :  0.4605722388725427 cross_val_score :  0.3166605370236611
# K value :  10  train score :  0.45099831872629736 cross_val_score :  0.3200245345755951
# K value :  11  train score :  0.4417179402930982 cross_val_score :  0.32289134632047867
# ...

# %%
cross_val_knn_regressor=max(cross_val_knn)

# %%
print("The best K-Value is 16 and Cross_val_score is",cross_val_knn_regressor )
# Out:
# The best K-Value is 16 and Cross_val_score is 0.326265069759798

# %%
knn_regressor=KNeighborsRegressor(n_neighbors=16)
knn_regressor.fit(X_train_scaled,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=16)

# %%
cross_val_knn_regressor=cross_val_score(knn_regressor,X_train_scaled,y_train,cv=15).mean()
cross_val_knn_regressor
# Out:
# 0.3262820407761009

# %% [markdown]
# DECISION TREE REGRESSION

# %%
from sklearn.tree import DecisionTreeRegressor

max_depth=np.arange(1,20)
cross_val_dt=[]
for d in max_depth:
    dt_regressor= DecisionTreeRegressor(max_depth=d, random_state=0)
    dt_regressor.fit(X_train,y_train)
    print("Depth : ", d, " train Score  : ", dt_regressor.score(X_train,y_train), "cross_val_score : ", cross_val_score(dt_regressor,X_train,y_train,cv = 10).mean())
    cross_val_dt.append(cross_val_score(dt_regressor,X_train,y_train,cv = 10).mean())
# Out:
# Depth :  1  train Score  :  0.0823495133092157 cross_val_score :  0.08199300504268178
# Depth :  2  train Score  :  0.26788624862185595 cross_val_score :  0.2673591295221232
# Depth :  3  train Score  :  0.3489346842477843 cross_val_score :  0.34799305307276074
# Depth :  4  train Score  :  0.37272065294967194 cross_val_score :  0.36882861713431375
# Depth :  5  train Score  :  0.39241091543201245 cross_val_score :  0.38642076197105213
# Depth :  6  train Score  :  0.40801167160274454 cross_val_score :  0.3980658149182538
# Depth :  7  train Score  :  0.42323328644044833 cross_val_score :  0.40238415659536536
# Depth :  8  train Score  :  0.4378990288336584 cross_val_score :  0.40037897077019863
# Depth :  9  train Score  :  0.4578461642132078 cross_val_score :  0.3979172643698743
# Depth :  10  train Score  :  0.47879772403691123 cross_val_score :  0.38747954802267326
# Depth :  11  train Score  :  0.5018748715235297 cross_val_score :  0.3759985699398055
# ...

# %%
cross_val_dt_regressor=max(cross_val_dt)

# %%
print("The best depth is 7 and Cross_val_score is:",cross_val_dt_regressor)
# Out:
# The best depth is 7 and Cross_val_score is: 0.40238415659536536

# %%
dt_regressor=DecisionTreeRegressor(max_depth=7, random_state=0)
dt_regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, random_state=0)

# %%
cross_val_dt_regressor=cross_val_score(dt_regressor,X_train,y_train,cv=10).mean()
cross_val_dt_regressor
# Out:
# 0.40238415659536536

# %%
ftImp = list(zip(dt_regressor.feature_importances_, df.columns[:-1]))
imp = pd.DataFrame(ftImp, columns = ["Importance","Feature"])
imp.sort_values("Importance",ascending = False,inplace=True)
imp
# Out:
#    Importance         Feature
# 1    0.444213             job
# 0    0.433695             age
# 3    0.040458  education_qual
# 2    0.033958         marital
# 5    0.025150             day
# 4    0.006461       call_type
# 9    0.006223    prev_outcome
# 6    0.005736             mon
# 7    0.003240             dur
# 8    0.000866       num_calls

# %% [markdown]
# RANDOM FOREST REGRESSION

# %%
from sklearn.ensemble import RandomForestRegressor

max_depth=np.array([2,4,8,10,11,12,13,15,18,20])
cross_val_rf=[]
for d in max_depth:
    rf_regressor=RandomForestRegressor(max_depth=d, random_state=0)
    rf_regressor.fit(X_train,y_train)  
    print("Depth : ", d, "cross_val_score : ", cross_val_score(rf_regressor,X_train,y_train,cv = 15).mean())
    cross_val_rf.append(cross_val_score(rf_regressor,X_train,y_train,cv = 15).mean())
# Out:
# Depth :  2 cross_val_score :  0.26723939537249775
# Depth :  4 cross_val_score :  0.3768129835952535
# Depth :  8 cross_val_score :  0.4240506655234644
# Depth :  10 cross_val_score :  0.43499474877053307
# Depth :  11 cross_val_score :  0.43776863968943913
# Depth :  12 cross_val_score :  0.4389862549139991
# Depth :  13 cross_val_score :  0.4387711258554485
# Depth :  15 cross_val_score :  0.4345818290516759
# Depth :  18 cross_val_score :  0.42416843463146103
# Depth :  20 cross_val_score :  0.4161762831604693

# %%
cross_val_rf_regressor=max(cross_val_rf)

# %%
print("The best depth is 12 and Cross_val_score is:",cross_val_rf_regressor)
# Out:
# The best depth is 12 and Cross_val_score is: 0.4389862549139991

# %%
rf_regressor=RandomForestRegressor(max_depth=12, random_state=0)
rf_regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=12, random_state=0)

# %%
cross_val_rf_regressor=cross_val_score(rf_regressor,X_train,y_train,cv=15).mean()
cross_val_rf_regressor
# Out:
# 0.4389862549139991

# %% [markdown]
# XG BOOST

# %%
import xgboost as xgb

cross_val_xgb=[]
for lr in [0.01,0.05,0.08,0.1,0.2,0.25,0.3]:
    xgb_regressor= xgb.XGBRegressor(learning_rate = lr,n_estimators=100)
    xgb_regressor.fit(X_train,y_train)
    print("Learning rate : ", lr,"cross_val_score:", cross_val_score(xgb_regressor,X_train,y_train,cv = 15).mean())
    cross_val_xgb.append(cross_val_score(xgb_regressor,X_train,y_train,cv = 15).mean())
# Out:
# Learning rate :  0.01 cross_val_score: 0.35634115897418633
# Learning rate :  0.05 cross_val_score: 0.44431329527370816
# Learning rate :  0.08 cross_val_score: 0.44989635266692396
# Learning rate :  0.1 cross_val_score: 0.45068975084423146
# Learning rate :  0.2 cross_val_score: 0.4452060026925881
# Learning rate :  0.25 cross_val_score: 0.44108746344724375
# Learning rate :  0.3 cross_val_score: 0.43581489772033005

# %%
cross_val_xgb_regressor=max(cross_val_xgb)

# %%
print("The best Learning rate is 0.1 and Cross_val_score is:",cross_val_xgb_regressor)
# Out:
# The best Learning rate is 0.1 and Cross_val_score is: 0.45068975084423146

# %%
xgb_regressor= xgb.XGBRegressor(learning_rate =0.1,n_estimators=100) # initialise the model
xgb_regressor.fit(X_train,y_train) #train the model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
cross_val_xgb_regressor=cross_val_score(xgb_regressor,X_train,y_train,cv=15).mean()
cross_val_xgb_regressor
# Out:
# 0.45068975084423146

# %%
print("Cross Validation Score for Linear Regression Model:",cross_val_linear_model)
print("Cross Validation Score for K-Nearest Neighbors Regression Model:",cross_val_knn_regressor)
print("Cross Validation Score for Decision Tree Regression Model: ",cross_val_dt_regressor)
print("Cross Validation Score for Random Forest Regression Model: ",cross_val_rf_regressor)
print("Cross Validation Score for Extreme-Gradient Boosting Regression Model: ",cross_val_xgb_regressor)
# Out:
# Cross Validation Score for Linear Regression Model: 0.05629461698293566
# Cross Validation Score for K-Nearest Neighbors Regression Model: 0.3262820407761009
# Cross Validation Score for Decision Tree Regression Model:  0.40238415659536536
# Cross Validation Score for Random Forest Regression Model:  0.4389862549139991
# Cross Validation Score for Extreme-Gradient Boosting Regression Model:  0.45068975084423146

# %% [markdown]
# CONCLUSION

# %%
xgb_regressor.feature_importances_
# Out:
# array([0.19931239, 0.57453054, 0.03888533, 0.06382377, 0.01958482,
#        0.03413122, 0.01180934, 0.01165766, 0.01542005, 0.03084482],
#       dtype=float32)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education_qual', 'call_type', 'day', 'mon',
#        'dur', 'num_calls', 'prev_outcome', 'y'],
#       dtype='object')

# %%
sorted_idx = xgb_regressor.feature_importances_.argsort()
plt.figure(figsize=(10,5))
plt.barh(df.columns[sorted_idx], xgb_regressor.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.title("Feature Importance")
plt.show()

# %%
xgb_regressor.feature_importances_
# Out:
# array([0.19931239, 0.57453054, 0.03888533, 0.06382377, 0.01958482,
#        0.03413122, 0.01180934, 0.01165766, 0.01542005, 0.03084482],
#       dtype=float32)

# %%
sorted_idx = xgb_regressor.feature_importances_.argsort()
plt.figure(figsize=(10,5))
plt.barh(df.columns[sorted_idx], xgb_regressor.feature_importances_[sorted_idx])
plt.xlabel("Extreme Gradient Boosting Feature Importance")
plt.title("Feature Importance")
plt.show()
